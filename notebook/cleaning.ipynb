# %%
import pandas as pd
from pathlib import Path

# %%
pd.set_option('display.max_columns', None)

# %%
gen_path = "../data/general_payments/cms_general_2024.csv"
res_path = "../data/research_payments/cms_research_2024.csv"

gen_usecols = [
    "Covered_Recipient_Profile_ID",
    "Covered_Recipient_NPI",
    "Covered_Recipient_First_Name",
    "Covered_Recipient_Last_Name",

    "Recipient_City",
    "Recipient_State",

    "Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID",
    "Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name",
    "Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1",

    "Total_Amount_of_Payment_USDollars",
    "Date_of_Payment",
    "Nature_of_Payment_or_Transfer_of_Value", # used strictly for filtering and dropped later
    "Record_ID",
    "Program_Year",
]

res_usecols = [
    "Covered_Recipient_Profile_ID",
    "Covered_Recipient_NPI",
    "Covered_Recipient_First_Name",
    "Covered_Recipient_Last_Name",

    "Recipient_City",
    "Recipient_State",

    "Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID",
    "Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name",
    "Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1",

    "Total_Amount_of_Payment_USDollars",
    "Date_of_Payment",
    "Record_ID",
    "Program_Year",
]

gen_df = pd.read_csv(gen_path, usecols=gen_usecols, low_memory=False)
gen_df = gen_df.reindex(columns=gen_usecols)

res_df = pd.read_csv(res_path, usecols=res_usecols, low_memory=False)
res_df = res_df.reindex(columns=res_usecols)

# %%
# CLEAN COLUMNS
print(gen_df.columns.tolist())
print(res_df.columns.tolist())

print([col.strip().lower() for col in gen_df.columns])
print([col.strip().lower() for col in res_df.columns])

gen_df.columns = [col.strip().lower() for col in gen_df.columns]
res_df.columns = [col.strip().lower() for col in res_df.columns]
# Out:
# ['Covered_Recipient_Profile_ID', 'Covered_Recipient_NPI', 'Covered_Recipient_First_Name', 'Covered_Recipient_Last_Name', 'Recipient_City', 'Recipient_State', 'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID', 'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name', 'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1', 'Total_Amount_of_Payment_USDollars', 'Date_of_Payment', 'Nature_of_Payment_or_Transfer_of_Value', 'Record_ID', 'Program_Year']
# ['Covered_Recipient_Profile_ID', 'Covered_Recipient_NPI', 'Covered_Recipient_First_Name', 'Covered_Recipient_Last_Name', 'Recipient_City', 'Recipient_State', 'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID', 'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name', 'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1', 'Total_Amount_of_Payment_USDollars', 'Date_of_Payment', 'Record_ID', 'Program_Year']
# ['covered_recipient_profile_id', 'covered_recipient_npi', 'covered_recipient_first_name', 'covered_recipient_last_name', 'recipient_city', 'recipient_state', 'applicable_manufacturer_or_applicable_gpo_making_payment_id', 'applicable_manufacturer_or_applicable_gpo_making_payment_name', 'name_of_drug_or_biological_or_device_or_medical_supply_1', 'total_amount_of_payment_usdollars', 'date_of_payment', 'nature_of_payment_or_transfer_of_value', 'record_id', 'program_year']
# ['covered_recipient_profile_id', 'covered_recipient_npi', 'covered_recipient_first_name', 'covered_recipient_last_name', 'recipient_city', 'recipient_state', 'applicable_manufacturer_or_applicable_gpo_making_payment_id', 'applicable_manufacturer_or_applicable_gpo_making_payment_name', 'name_of_drug_or_biological_or_device_or_medical_supply_1', 'total_amount_of_payment_usdollars', 'date_of_payment', 'record_id', 'program_year']

# %%
# FILTER UNRELATED PAYMENT NATURES SUCH AS FOOD AND DRINKS
useful_natures = [
    "Compensation for services other than consulting, including serving as faculty or as a speaker at a venue other than a continuing education program",
    "Consulting Fee",
    "Education",
    "Honoraria",
    "Royalty or License",
    "Compensation for serving as faculty or as a speaker for a medical education program",
    "Long term medical supply or device loan",
    "Grant",
]

print(len(gen_df))
gen_df = gen_df[gen_df['nature_of_payment_or_transfer_of_value'].isin(useful_natures)]
print(len(gen_df))
# Out:
# 15397627
# 649560

# %%
# DROP NATURES USED FOR FILTERING TO CONCAT LATER
gen_df.drop(columns=["nature_of_payment_or_transfer_of_value"], inplace=True)
display(gen_df.head())
# Out:
#    covered_recipient_profile_id  covered_recipient_npi  \
# 0                           NaN                    NaN
# 1                           NaN                    NaN
# 2                           NaN                    NaN
# 3                           NaN                    NaN
# 4                           NaN                    NaN
#
#   covered_recipient_first_name covered_recipient_last_name recipient_city  \
# 0                          NaN                         NaN    New Orleans
# 1                          NaN                         NaN      Nashville
# 2                          NaN                         NaN      LA CROSSE
# 3                          NaN                         NaN      LA CROSSE
# 4                          NaN                         NaN      LA CROSSE
#
#   recipient_state  \
# 0              LA
# 1              TN
# 2              WI
# 3              WI
# 4              WI
#
#    applicable_manufacturer_or_applicable_gpo_making_payment_id  \
# 0                                       100000000226
# 1                                       100000000226
# 2                                       100000686813
# 3                                       100000686813
# 4                                       100000686813
#
#   applicable_manufacturer_or_applicable_gpo_making_payment_name  \
# 0                                Genentech USA, Inc.
# 1                                Genentech USA, Inc.
# 2                         Linde Gas & Equipment Inc.
# 3                         Linde Gas & Equipment Inc.
# 4                         Linde Gas & Equipment Inc.
#
#   name_of_drug_or_biological_or_device_or_medical_supply_1  \
# 0                                            Ocrevus
# 1                                             Polivy
# 2                                        REQNOXBOX-I
# 3                                        REQNOXBOX-I
# 4                                        REQNOXBOX-I
#
#    total_amount_of_payment_usdollars date_of_payment   record_id  program_year
# 0                            10000.0      02/23/2024  1133195830          2024
# 1                             5000.0      08/01/2024  1133196475          2024
# 2                              330.0      02/13/2024  1142632901          2024
# 3                              330.0      08/06/2024  1142632912          2024
# 4                              330.0      02/08/2024  1142632930          2024

# %%
print(gen_df['covered_recipient_npi'].isnull().sum())
print(res_df['covered_recipient_npi'].isnull().sum())
# Out:
# 21525
# 728842

# %%
gen_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 649560 entries, 0 to 15397507
# Data columns (total 13 columns):
#  #   Column                                                         Non-Null Count   Dtype
# ---  ------                                                         --------------   -----
#  0   covered_recipient_profile_id                                   629267 non-null  float64
#  1   covered_recipient_npi                                          628035 non-null  float64
#  2   covered_recipient_first_name                                   629262 non-null  object
#  3   covered_recipient_last_name                                    629253 non-null  object
#  4   recipient_city                                                 649560 non-null  object
#  5   recipient_state                                                649514 non-null  object
#  6   applicable_manufacturer_or_applicable_gpo_making_payment_id    649560 non-null  int64
#  7   applicable_manufacturer_or_applicable_gpo_making_payment_name  649560 non-null  object
#  8   name_of_drug_or_biological_or_device_or_medical_supply_1       459156 non-null  object
#  9   total_amount_of_payment_usdollars                              649560 non-null  float64
#  10  date_of_payment                                                649560 non-null  object
#  11  record_id                                                      649560 non-null  int64
#  12  program_year                                                   649560 non-null  int64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 69.4+ MB

# %%
# DROP NA IF IMPORTANT VALUES MISSING, EX. LINK TO PHYSICIANS
subset = [
    "covered_recipient_npi",
    "total_amount_of_payment_usdollars",
    "date_of_payment",
]

print(len(gen_df))
gen_df = gen_df.dropna(subset=subset)
print(len(gen_df))

print(len(res_df))
res_df = res_df.dropna(subset=subset)
print(len(res_df))
# Out:
# 649560
# 628035
# 756193
# 27351

# %%
# DATA TYPES AND CLEANING 
gen_df["covered_recipient_profile_id"] = gen_df["covered_recipient_profile_id"].astype("Int64")
gen_df["covered_recipient_npi"] = gen_df["covered_recipient_npi"].astype("Int64")

gen_df["covered_recipient_first_name"] = gen_df["covered_recipient_first_name"].str.strip()
gen_df["covered_recipient_last_name"] = gen_df["covered_recipient_last_name"].str.strip()

gen_df["recipient_city"] = gen_df["recipient_city"].str.strip().str.title()
gen_df["recipient_state"] = gen_df["recipient_state"].str.strip().str.upper()

gen_df["applicable_manufacturer_or_applicable_gpo_making_payment_id"] = gen_df["applicable_manufacturer_or_applicable_gpo_making_payment_id"].astype("Int64")
gen_df["applicable_manufacturer_or_applicable_gpo_making_payment_name"] = gen_df["applicable_manufacturer_or_applicable_gpo_making_payment_name"].str.strip()

gen_df["date_of_payment"] = pd.to_datetime(gen_df["date_of_payment"], format="%m/%d/%Y", errors="coerce")

gen_df["record_id"] = gen_df["record_id"].astype("Int64")
gen_df["program_year"] = gen_df["program_year"].astype("Int64")

res_df["covered_recipient_profile_id"] = res_df["covered_recipient_profile_id"].astype("Int64")
res_df["covered_recipient_npi"] = res_df["covered_recipient_npi"].astype("Int64")

res_df["covered_recipient_first_name"] = res_df["covered_recipient_first_name"].str.strip()
res_df["covered_recipient_last_name"] = res_df["covered_recipient_last_name"].str.strip()

res_df["recipient_city"] = res_df["recipient_city"].str.strip().str.title()
res_df["recipient_state"] = res_df["recipient_state"].str.strip().str.upper()

res_df["applicable_manufacturer_or_applicable_gpo_making_payment_id"] = res_df["applicable_manufacturer_or_applicable_gpo_making_payment_id"].astype("Int64")
res_df["applicable_manufacturer_or_applicable_gpo_making_payment_name"] = res_df["applicable_manufacturer_or_applicable_gpo_making_payment_name"].str.strip()

res_df["date_of_payment"] = pd.to_datetime(res_df["date_of_payment"], format="%m/%d/%Y", errors="coerce")

res_df["record_id"] = res_df["record_id"].astype("Int64")
res_df["program_year"] = res_df["program_year"].astype("Int64")

# %%
# ADD TRANSACTION FLAG
gen_df["transaction_type"] = "general"
res_df["transaction_type"] = "research"

# %%
gen_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 628035 entries, 11 to 15397486
# Data columns (total 14 columns):
#  #   Column                                                         Non-Null Count   Dtype
# ---  ------                                                         --------------   -----
#  0   covered_recipient_profile_id                                   628035 non-null  Int64
#  1   covered_recipient_npi                                          628035 non-null  Int64
#  2   covered_recipient_first_name                                   628030 non-null  object
#  3   covered_recipient_last_name                                    628022 non-null  object
#  4   recipient_city                                                 628035 non-null  object
#  5   recipient_state                                                627993 non-null  object
#  6   applicable_manufacturer_or_applicable_gpo_making_payment_id    628035 non-null  Int64
#  7   applicable_manufacturer_or_applicable_gpo_making_payment_name  628035 non-null  object
#  8   name_of_drug_or_biological_or_device_or_medical_supply_1       445204 non-null  object
#  9   total_amount_of_payment_usdollars                              628035 non-null  float64
#  10  date_of_payment                                                627974 non-null  datetime64[ns]
#  11  record_id                                                      628035 non-null  Int64
#  12  program_year                                                   628035 non-null  Int64
#  13  transaction_type                                               628035 non-null  object
# dtypes: Int64(5), datetime64[ns](1), float64(1), object(7)
# memory usage: 74.9+ MB

# %%
gen_df.head(10)
# Out:
#      covered_recipient_profile_id  covered_recipient_npi  \
# 11                         263830             1821102930
# 12                         263830             1821102930
# 13                         307418             1760577639
# 15                         307418             1760577639
# 337                        337143             1427041557
# 339                        337143             1427041557
# 342                        154556             1417981580
# 395                        984959             1821257130
# 485                        380039             1609061837
# 489                        263830             1821102930
#
#     covered_recipient_first_name covered_recipient_last_name   recipient_city  \
# 11                        DONALD                    GRIFFITH          Houston
# 12                        DONALD                    GRIFFITH          Houston
# 13                        DONALD                        LAMM  Paradise Valley
# 15                        DONALD                        LAMM  Paradise Valley
# 337                      MICHAEL                    SCHWARTZ            Plano
# 339                      MICHAEL                    SCHWARTZ            Plano
# 342                        KEITH                      WATSON       Fort Worth
# 395                        DAVID                  KUMMERFELD            Tyler
# 485                        DAVID                    ANDORSKY          Boulder
# 489                       DONALD                    GRIFFITH          Houston
#
#     recipient_state  \
# 11               TX
# 12               TX
# 13               AZ
# 15               AZ
# 337              TX
# 339              TX
# 342              TX
# 395              TX
# 485              CO
# 489              TX
#
#      applicable_manufacturer_or_applicable_gpo_making_payment_id  \
# 11                                        100000000186
# 12                                        100000000186
# 13                                        100000000186
# 15                                        100000000186
# 337                                       100000401809
# 339                                       100000401809
# 342                                       100000401809
# 395                                       100000401809
# 485                                       100000005526
# 489                                       100000000186
#
#     applicable_manufacturer_or_applicable_gpo_making_payment_name  \
# 11                           Mission Pharmacal Company
# 12                           Mission Pharmacal Company
# 13                           Mission Pharmacal Company
# 15                           Mission Pharmacal Company
# 337                                  Tigon Medical LLC
# 339                                  Tigon Medical LLC
# 342                                  Tigon Medical LLC
# 395                                  Tigon Medical LLC
# 485                              Ipsen Bioscience Inc.
# 489                          Mission Pharmacal Company
#
#     name_of_drug_or_biological_or_device_or_medical_supply_1  \
# 11                                           LITHOSTAT
# 12                                           LITHOSTAT
# 13                                                 NaN
# 15                                                 NaN
# 337                                                NaN
# 339                                                NaN
# 342                                                NaN
# 395                                                NaN
# 485                                                NaN
# 489                                          LITHOSTAT
#
#      total_amount_of_payment_usdollars date_of_payment   record_id  \
# 11                            19223.51      2024-08-22  1063488454
# 12                            16127.18      2024-11-27  1063488487
# 13                             1188.29      2024-08-22  1063488488
# 15                             1317.91      2024-11-27  1063488498
# 337                             925.00      2024-04-30  1067494116
# 339                             250.00      2024-07-24  1067494119
# 342                            1575.00      2024-04-30  1067494124
# 395                            1600.00      2024-07-24  1067523761
# 485                            1230.00      2024-09-20  1067524300
# 489                           15856.41      2024-02-29  1063864556
#
#      program_year transaction_type
# 11           2024          general
# 12           2024          general
# 13           2024          general
# 15           2024          general
# 337          2024          general
# 339          2024          general
# 342          2024          general
# 395          2024          general
# 485          2024          general
# 489          2024          general

# %%
column_order = [
        "covered_recipient_profile_id",
        "covered_recipient_npi",
        "covered_recipient_first_name",
        "covered_recipient_last_name",
        "recipient_city",
        "recipient_state",
        "applicable_manufacturer_or_applicable_gpo_making_payment_id",
        "applicable_manufacturer_or_applicable_gpo_making_payment_name",
        "name_of_drug_or_biological_or_device_or_medical_supply_1",
        "total_amount_of_payment_usdollars",
        "date_of_payment",
        "record_id",
        "program_year",
        "transaction_type"
]

gen_df = gen_df[column_order]
res_df = res_df[column_order]
print(len(gen_df))
print(len(res_df))
# Out:
# 628035
# 27351

# %%
unified_df = pd.concat([gen_df, res_df], ignore_index=True)
display(unified_df.head(10))

unified_df.info()
# Out:
#    covered_recipient_profile_id  covered_recipient_npi  \
# 0                        263830             1821102930
# 1                        263830             1821102930
# 2                        307418             1760577639
# 3                        307418             1760577639
# 4                        337143             1427041557
# 5                        337143             1427041557
# 6                        154556             1417981580
# 7                        984959             1821257130
# 8                        380039             1609061837
# 9                        263830             1821102930
#
#   covered_recipient_first_name covered_recipient_last_name   recipient_city  \
# 0                       DONALD                    GRIFFITH          Houston
# 1                       DONALD                    GRIFFITH          Houston
# 2                       DONALD                        LAMM  Paradise Valley
# 3                       DONALD                        LAMM  Paradise Valley
# 4                      MICHAEL                    SCHWARTZ            Plano
# 5                      MICHAEL                    SCHWARTZ            Plano
# 6                        KEITH                      WATSON       Fort Worth
# 7                        DAVID                  KUMMERFELD            Tyler
# 8                        DAVID                    ANDORSKY          Boulder
# 9                       DONALD                    GRIFFITH          Houston
#
#   recipient_state  \
# 0              TX
# 1              TX
# 2              AZ
# 3              AZ
# 4              TX
# 5              TX
# 6              TX
# 7              TX
# 8              CO
# 9              TX
#
#    applicable_manufacturer_or_applicable_gpo_making_payment_id  \
# 0                                       100000000186
# 1                                       100000000186
# 2                                       100000000186
# 3                                       100000000186
# 4                                       100000401809
# 5                                       100000401809
# 6                                       100000401809
# 7                                       100000401809
# 8                                       100000005526
# 9                                       100000000186
#
#   applicable_manufacturer_or_applicable_gpo_making_payment_name  \
# 0                          Mission Pharmacal Company
# 1                          Mission Pharmacal Company
# 2                          Mission Pharmacal Company
# 3                          Mission Pharmacal Company
# 4                                  Tigon Medical LLC
# 5                                  Tigon Medical LLC
# 6                                  Tigon Medical LLC
# 7                                  Tigon Medical LLC
# 8                              Ipsen Bioscience Inc.
# 9                          Mission Pharmacal Company
#
#   name_of_drug_or_biological_or_device_or_medical_supply_1  \
# 0                                          LITHOSTAT
# 1                                          LITHOSTAT
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                          LITHOSTAT
#
#    total_amount_of_payment_usdollars date_of_payment   record_id  \
# 0                           19223.51      2024-08-22  1063488454
# 1                           16127.18      2024-11-27  1063488487
# 2                            1188.29      2024-08-22  1063488488
# 3                            1317.91      2024-11-27  1063488498
# 4                             925.00      2024-04-30  1067494116
# 5                             250.00      2024-07-24  1067494119
# 6                            1575.00      2024-04-30  1067494124
# 7                            1600.00      2024-07-24  1067523761
# 8                            1230.00      2024-09-20  1067524300
# 9                           15856.41      2024-02-29  1063864556
#
#    program_year transaction_type
# 0          2024          general
# 1          2024          general
# 2          2024          general
# 3          2024          general
# 4          2024          general
# 5          2024          general
# 6          2024          general
# 7          2024          general
# 8          2024          general
# 9          2024          general
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 655386 entries, 0 to 655385
# Data columns (total 14 columns):
#  #   Column                                                         Non-Null Count   Dtype
# ---  ------                                                         --------------   -----
#  0   covered_recipient_profile_id                                   655386 non-null  Int64
#  1   covered_recipient_npi                                          655386 non-null  Int64
#  2   covered_recipient_first_name                                   655381 non-null  object
#  3   covered_recipient_last_name                                    655373 non-null  object
#  4   recipient_city                                                 655386 non-null  object
#  5   recipient_state                                                655343 non-null  object
#  6   applicable_manufacturer_or_applicable_gpo_making_payment_id    655386 non-null  Int64
#  7   applicable_manufacturer_or_applicable_gpo_making_payment_name  655386 non-null  object
#  8   name_of_drug_or_biological_or_device_or_medical_supply_1       460381 non-null  object
#  9   total_amount_of_payment_usdollars                              655386 non-null  float64
#  10  date_of_payment                                                655325 non-null  datetime64[ns]
#  11  record_id                                                      655386 non-null  Int64
#  12  program_year                                                   655386 non-null  Int64
#  13  transaction_type                                               655386 non-null  object
# dtypes: Int64(5), datetime64[ns](1), float64(1), object(7)
# memory usage: 73.1+ MB

# %%
print(len(unified_df))
no_dupes = unified_df.drop_duplicates()
print(len(no_dupes))
# Out:
# 655386
# 655386

# %%
export_path = Path("../exports/cms_unified_2024.csv")
#export_path.parent.mkdir(parents=True, exist_ok=True)
#unified_df.to_csv(export_path, index=False, encoding="utf-8")

# %%
unified_df.sample(10)
# Out:
#         covered_recipient_profile_id  covered_recipient_npi  \
# 226233                        271171             1962601047
# 133329                         27964             1619023223
# 364435                        193455             1275624660
# 401880                         23618             1528008588
# 367952                        258371             1689867434
# 401349                       8176691             1821400839
# 456824                      11344113             1033567409
# 603354                       1022999             1164643094
# 431835                      11076366             1538792833
# 167641                         71913             1578858973
#
#        covered_recipient_first_name covered_recipient_last_name  \
# 226233               MOHAMMADBAGHER                       ZIARI
# 133329                         Syed                     Mustafa
# 364435                      RAJVEER                     SACHDEV
# 401880                            R                   RASMUSSEN
# 367952                     JONATHON                     CHAPMAN
# 401349                        JAMIE                        TUNG
# 456824                        SEYED                       ABEDI
# 603354                          AMY                      GIMLEN
# 431835                     JENNIFER                      MCBAIN
# 167641                      ALIREZA                     ASHRAFI
#
#          recipient_city recipient_state  \
# 226233           Corona              CA
# 133329        Rochester              NY
# 364435      Garnerville              NY
# 401880            Provo              UT
# 367952      Baton Rouge              LA
# 401349        Palo Alto              CA
# 456824       Cedar Park              TX
# 603354  Manhattan Beach              CA
# 431835           Albany              NY
# 167641       Middleboro              MA
#
#         applicable_manufacturer_or_applicable_gpo_making_payment_id  \
# 226233                                       100000136416
# 133329                                       100000000146
# 364435                                       100000000066
# 401880                                       100000005384
# 367952                                       100000000066
# 401349                                       100000005384
# 456824                                       100000000263
# 603354                                       100000005613
# 431835                                       100000000137
# 167641                                       100000005689
#
#        applicable_manufacturer_or_applicable_gpo_making_payment_name  \
# 226233               Regeneron Healthcare Solutions, Inc.
# 133329                     AstraZeneca Pharmaceuticals LP
# 364435                                     Lilly USA, LLC
# 401880                           INTUITIVE SURGICAL, INC.
# 367952                                     Lilly USA, LLC
# 401349                           INTUITIVE SURGICAL, INC.
# 456824                                 Incyte Corporation
# 603354                             Align Technology, Inc.
# 431835                             Astellas Pharma US Inc
# 167641                                  Straumann USA LLC
#
#        name_of_drug_or_biological_or_device_or_medical_supply_1  \
# 226233                                            LIBTAYO
# 133329                                            FASENRA
# 364435                                           MOUNJARO
# 401880                           Da Vinci Surgical System
# 367952                                              OMVOH
# 401349                                         DAVINCI XI
# 456824                                                NaN
# 603354                                         Invisalign
# 431835                                                NaN
# 167641                                                NaN
#
#         total_amount_of_payment_usdollars date_of_payment   record_id  \
# 226233                            3136.00      2024-10-24  1114262157
# 133329                            2150.00      2024-06-28  1104462594
# 364435                             750.00      2024-01-25  1135330749
# 401880                            2000.00      2024-02-14  1137239443
# 367952                            2500.00      2024-06-10  1135080936
# 401349                            1000.00      2024-06-12  1137226449
# 456824                              74.99      2024-12-04  1141273020
# 603354                              75.00      2024-02-20  1153235006
# 431835                              84.99      2024-04-22  1139508129
# 167641                              33.24      2024-04-08  1106601716
#
#         program_year transaction_type
# 226233          2024          general
# 133329          2024          general
# 364435          2024          general
# 401880          2024          general
# 367952          2024          general
# 401349          2024          general
# 456824          2024          general
# 603354          2024          general
# 431835          2024          general
# 167641          2024          general
