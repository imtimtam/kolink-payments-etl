# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
gen_path = "../data/general_payments/cms_general_2024.csv"
res_path = "../data/research_payments/cms_research_2024.csv"

gen_usecols = [
    "Covered_Recipient_Profile_ID",
    "Covered_Recipient_NPI",
    "Covered_Recipient_First_Name",
    "Covered_Recipient_Last_Name",

    "Recipient_City",
    "Recipient_State",

    "Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID",
    "Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name",
    "Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1",

    "Total_Amount_of_Payment_USDollars",
    "Date_of_Payment",
    "Nature_of_Payment_or_Transfer_of_Value", # used strictly for filtering and dropped later
    "Record_ID",
    "Program_Year",
]

res_usecols = [
    "Covered_Recipient_Profile_ID",
    "Covered_Recipient_NPI",
    "Covered_Recipient_First_Name",
    "Covered_Recipient_Last_Name",

    "Recipient_City",
    "Recipient_State",

    "Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID",
    "Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name",
    "Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1",

    "Total_Amount_of_Payment_USDollars",
    "Date_of_Payment",
    "Record_ID",
    "Program_Year",
]

gen_df = pd.read_csv(gen_path, usecols=gen_usecols, low_memory=False)
gen_df = gen_df.reindex(columns=gen_usecols)

res_df = pd.read_csv(res_path, usecols=res_usecols, low_memory=False)
res_df = res_df.reindex(columns=res_usecols)

# %%
# CLEAN COLUMNS
print(gen_df.columns.tolist())
print(res_df.columns.tolist())

print([col.strip().lower() for col in gen_df.columns])
print([col.strip().lower() for col in res_df.columns])

gen_df.columns = [col.strip().lower() for col in gen_df.columns]
res_df.columns = [col.strip().lower() for col in res_df.columns]
# Out:
# ['Covered_Recipient_Profile_ID', 'Covered_Recipient_NPI', 'Covered_Recipient_First_Name', 'Covered_Recipient_Last_Name', 'Recipient_City', 'Recipient_State', 'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID', 'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name', 'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1', 'Total_Amount_of_Payment_USDollars', 'Date_of_Payment', 'Nature_of_Payment_or_Transfer_of_Value', 'Record_ID', 'Program_Year']
# ['Covered_Recipient_Profile_ID', 'Covered_Recipient_NPI', 'Covered_Recipient_First_Name', 'Covered_Recipient_Last_Name', 'Recipient_City', 'Recipient_State', 'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID', 'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name', 'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1', 'Total_Amount_of_Payment_USDollars', 'Date_of_Payment', 'Record_ID', 'Program_Year']
# ['covered_recipient_profile_id', 'covered_recipient_npi', 'covered_recipient_first_name', 'covered_recipient_last_name', 'recipient_city', 'recipient_state', 'applicable_manufacturer_or_applicable_gpo_making_payment_id', 'applicable_manufacturer_or_applicable_gpo_making_payment_name', 'name_of_drug_or_biological_or_device_or_medical_supply_1', 'total_amount_of_payment_usdollars', 'date_of_payment', 'nature_of_payment_or_transfer_of_value', 'record_id', 'program_year']
# ['covered_recipient_profile_id', 'covered_recipient_npi', 'covered_recipient_first_name', 'covered_recipient_last_name', 'recipient_city', 'recipient_state', 'applicable_manufacturer_or_applicable_gpo_making_payment_id', 'applicable_manufacturer_or_applicable_gpo_making_payment_name', 'name_of_drug_or_biological_or_device_or_medical_supply_1', 'total_amount_of_payment_usdollars', 'date_of_payment', 'record_id', 'program_year']

# %%
# FILTER UNRELATED PAYMENT NATURES SUCH AS FOOD AND DRINKS
useful_natures = [
    "Compensation for services other than consulting, including serving as faculty or as a speaker at a venue other than a continuing education program",
    "Consulting Fee",
    "Education",
    "Honoraria",
    "Royalty or License",
    "Compensation for serving as faculty or as a speaker for a medical education program",
    "Long term medical supply or device loan",
    "Grant",
]

print(len(gen_df))
gen_df = gen_df[gen_df['nature_of_payment_or_transfer_of_value'].isin(useful_natures)]
print(len(gen_df))
# Out:
# 15397627
# 649560

# %%
# DROP NATURES USED FOR FILTERING TO CONCAT LATER
gen_df.drop("nature_of_payment_or_transfer_of_value", axis=1, inplace=True)
display(gen_df.head())
# Out:
#    covered_recipient_profile_id  covered_recipient_npi  \
# 0                           NaN                    NaN
# 1                           NaN                    NaN
# 2                           NaN                    NaN
# 3                           NaN                    NaN
# 4                           NaN                    NaN
#
#   covered_recipient_first_name covered_recipient_last_name recipient_city  \
# 0                          NaN                         NaN    New Orleans
# 1                          NaN                         NaN      Nashville
# 2                          NaN                         NaN      LA CROSSE
# 3                          NaN                         NaN      LA CROSSE
# 4                          NaN                         NaN      LA CROSSE
#
#   recipient_state  \
# 0              LA
# 1              TN
# 2              WI
# 3              WI
# 4              WI
#
#    applicable_manufacturer_or_applicable_gpo_making_payment_id  \
# 0                                       100000000226
# 1                                       100000000226
# 2                                       100000686813
# 3                                       100000686813
# 4                                       100000686813
#
#   applicable_manufacturer_or_applicable_gpo_making_payment_name  \
# 0                                Genentech USA, Inc.
# 1                                Genentech USA, Inc.
# 2                         Linde Gas & Equipment Inc.
# 3                         Linde Gas & Equipment Inc.
# 4                         Linde Gas & Equipment Inc.
#
#   name_of_drug_or_biological_or_device_or_medical_supply_1  \
# 0                                            Ocrevus
# 1                                             Polivy
# 2                                        REQNOXBOX-I
# 3                                        REQNOXBOX-I
# 4                                        REQNOXBOX-I
#
#    total_amount_of_payment_usdollars date_of_payment   record_id  program_year
# 0                            10000.0      02/23/2024  1133195830          2024
# 1                             5000.0      08/01/2024  1133196475          2024
# 2                              330.0      02/13/2024  1142632901          2024
# 3                              330.0      08/06/2024  1142632912          2024
# 4                              330.0      02/08/2024  1142632930          2024

# %%
print(gen_df['covered_recipient_npi'].isnull().sum())
print(res_df['covered_recipient_npi'].isnull().sum())
# Out:
# 21525
# 728842

# %%
subset = [
    "covered_recipient_npi",
    "total_amount_of_payment_usdollars",
    "date_of_payment",
]

print(len(gen_df))
gen_df = gen_df.dropna(subset=subset)
print(len(gen_df))

print(len(res_df))
res_df = res_df.dropna(subset=subset)
print(len(res_df))
# Out:
# 649560
# 628035
# 756193
# 27351

# %%
df["covered_recipient_profile_id"] = df["covered_recipient_profile_id"].astype("Int64")
df["covered_recipient_npi"] = df["covered_recipient_npi"].astype("Int64")

df["covered_recipient_first_name"] = df["covered_recipient_first_name"].str.strip()
df["covered_recipient_last_name"] = df["covered_recipient_last_name"].str.strip()

df["covered_recipient_specialty_1"] = df["covered_recipient_specialty_1"].str.strip().str.title()
df["covered_recipient_primary_type_1"] = df["covered_recipient_primary_type_1"].str.strip().str.title()
df["covered_recipient_license_state_code1"] = df["covered_recipient_license_state_code1"].str.strip().str.upper()
df["recipient_city"] = df["recipient_city"].str.strip().str.title()
df["recipient_state"] = df["recipient_state"].str.strip().str.upper()
df["recipient_zip_code"] = df["recipient_zip_code"].str.strip()
df["applicable_manufacturer_or_applicable_gpo_making_payment_name"] = df["applicable_manufacturer_or_applicable_gpo_making_payment_name"].str.strip()

df["date_of_payment"] = pd.to_datetime(df["date_of_payment"], format="%m/%d/%Y", errors="coerce")
df["nature_of_payment_or_transfer_of_value"] = df["nature_of_payment_or_transfer_of_value"].str.strip()
df["form_of_payment_or_transfer_of_value"] = df["form_of_payment_or_transfer_of_value"].str.strip()

bool_map = {"Yes": True, "No": False}
df["physician_ownership_indicator"] = df["physician_ownership_indicator"].map(bool_map).astype("boolean").fillna(False)

# %%
id_columns = [
    "covered_recipient_profile_id",
    "covered_recipient_npi",
    "applicable_manufacturer_or_applicable_gpo_making_payment_id",
    "number_of_payments_included_in_total_amount",
    "record_id",
    "program_year",
]

for col in id_columns:
    df[col] = df[col].astype("Int64")

# %%
df["recipient_zip_5"] = df["recipient_zip_code"].str[:5]
df.head()
# Out:
#    covered_recipient_profile_id  covered_recipient_npi  \
# 0                      11107494             1871018762
# 1                       1389841             1861886830
# 2                       5703924             1861847113
# 3                        892163             1588894869
# 4                        892163             1588894869
#
#   covered_recipient_first_name covered_recipient_last_name  \
# 0                       ROANNA                      EGGERT
# 1                         REZA                  GORAVANCHI
# 2                       LAUREN                      WILSON
# 3                       RACHEL                        CARR
# 4                       RACHEL                        CARR
#
#                        covered_recipient_specialty_1  \
# 0  Physician Assistants & Advanced Practice Nursi...
# 1  Allopathic & Osteopathic Physicians|Psychiatry...
# 2  Allopathic & Osteopathic Physicians|Psychiatry...
# 3  Allopathic & Osteopathic Physicians|Obstetrics...
# 4  Allopathic & Osteopathic Physicians|Obstetrics...
#
#   covered_recipient_primary_type_1 covered_recipient_license_state_code1  \
# 0               Nurse Practitioner                                    FL
# 1                   Medical Doctor                                    NV
# 2                   Medical Doctor                                    TX
# 3                   Medical Doctor                                    IN
# 4                   Medical Doctor                                    IN
#
#   recipient_city recipient_state recipient_zip_code  \
# 0  Pinellas Park              FL              33781
# 1      Las Vegas              NV              89103
# 2    New Orleans              LA              70112
# 3  Indianapolisq              IN         46256-4649
# 4  Indianapolisq              IN         46256-4649
#
#    applicable_manufacturer_or_applicable_gpo_making_payment_id  \
# 0                                       100000005450
# 1                                       100000005450
# 2                                       100000005450
# 3                                       100000151631
# 4                                       100000151631
#
#   applicable_manufacturer_or_applicable_gpo_making_payment_name  \
# 0                                  Neuronetics, Inc.
# 1                                  Neuronetics, Inc.
# 2                                  Neuronetics, Inc.
# 3                              Minerva Surgical, Inc
# 4                              Minerva Surgical, Inc
#
#   name_of_drug_or_biological_or_device_or_medical_supply_1  \
# 0                       NEUROSTAR TMS THERAPY SYSTEM
# 1                       NEUROSTAR TMS THERAPY SYSTEM
# 2                       NEUROSTAR TMS THERAPY SYSTEM
# 3                                                NaN
# 4                                                NaN
#
#    total_amount_of_payment_usdollars date_of_payment  \
# 0                              39.62      2023-04-28
# 1                              19.27      2023-02-14
# 2                              23.75      2023-01-25
# 3                              14.59      2023-02-02
# 4                              22.17      2023-06-20
#
#   nature_of_payment_or_transfer_of_value form_of_payment_or_transfer_of_value  \
# 0                      Food and Beverage              Cash or cash equivalent
# 1                      Food and Beverage              Cash or cash equivalent
# 2                      Food and Beverage              Cash or cash equivalent
# 3                      Food and Beverage           In-kind items and services
# 4                      Food and Beverage           In-kind items and services
#
#    number_of_payments_included_in_total_amount  record_id  \
# 0                                            1  966803191
# 1                                            1  966803197
# 2                                            1  966803203
# 3                                            1  966519119
# 4                                            1  966519125
#
#    physician_ownership_indicator  program_year recipient_zip_5
# 0                          False          2023           33781
# 1                          False          2023           89103
# 2                          False          2023           70112
# 3                          False          2023           46256
# 4                          False          2023           46256

# %%
df = df[
    [
        "covered_recipient_profile_id",
        "covered_recipient_npi",
        "covered_recipient_first_name",
        "covered_recipient_last_name",
        "covered_recipient_specialty_1",
        "covered_recipient_primary_type_1",
        "covered_recipient_license_state_code1",
        "recipient_city",
        "recipient_state",
        "recipient_zip_code",
        "recipient_zip_5",
        "applicable_manufacturer_or_applicable_gpo_making_payment_id",
        "applicable_manufacturer_or_applicable_gpo_making_payment_name",
        "name_of_drug_or_biological_or_device_or_medical_supply_1",
        "total_amount_of_payment_usdollars",
        "date_of_payment",
        "nature_of_payment_or_transfer_of_value",
        "form_of_payment_or_transfer_of_value",
        "number_of_payments_included_in_total_amount",
        "record_id",
        "physician_ownership_indicator",
        "program_year",
    ]
]
df.head()
# Out:
#    covered_recipient_profile_id  covered_recipient_npi  \
# 0                      11107494             1871018762
# 1                       1389841             1861886830
# 2                       5703924             1861847113
# 3                        892163             1588894869
# 4                        892163             1588894869
#
#   covered_recipient_first_name covered_recipient_last_name  \
# 0                       ROANNA                      EGGERT
# 1                         REZA                  GORAVANCHI
# 2                       LAUREN                      WILSON
# 3                       RACHEL                        CARR
# 4                       RACHEL                        CARR
#
#                        covered_recipient_specialty_1  \
# 0  Physician Assistants & Advanced Practice Nursi...
# 1  Allopathic & Osteopathic Physicians|Psychiatry...
# 2  Allopathic & Osteopathic Physicians|Psychiatry...
# 3  Allopathic & Osteopathic Physicians|Obstetrics...
# 4  Allopathic & Osteopathic Physicians|Obstetrics...
#
#   covered_recipient_primary_type_1 covered_recipient_license_state_code1  \
# 0               Nurse Practitioner                                    FL
# 1                   Medical Doctor                                    NV
# 2                   Medical Doctor                                    TX
# 3                   Medical Doctor                                    IN
# 4                   Medical Doctor                                    IN
#
#   recipient_city recipient_state recipient_zip_code recipient_zip_5  \
# 0  Pinellas Park              FL              33781           33781
# 1      Las Vegas              NV              89103           89103
# 2    New Orleans              LA              70112           70112
# 3  Indianapolisq              IN         46256-4649           46256
# 4  Indianapolisq              IN         46256-4649           46256
#
#    applicable_manufacturer_or_applicable_gpo_making_payment_id  \
# 0                                       100000005450
# 1                                       100000005450
# 2                                       100000005450
# 3                                       100000151631
# 4                                       100000151631
#
#   applicable_manufacturer_or_applicable_gpo_making_payment_name  \
# 0                                  Neuronetics, Inc.
# 1                                  Neuronetics, Inc.
# 2                                  Neuronetics, Inc.
# 3                              Minerva Surgical, Inc
# 4                              Minerva Surgical, Inc
#
#   name_of_drug_or_biological_or_device_or_medical_supply_1  \
# 0                       NEUROSTAR TMS THERAPY SYSTEM
# 1                       NEUROSTAR TMS THERAPY SYSTEM
# 2                       NEUROSTAR TMS THERAPY SYSTEM
# 3                                                NaN
# 4                                                NaN
#
#    total_amount_of_payment_usdollars date_of_payment  \
# 0                              39.62      2023-04-28
# 1                              19.27      2023-02-14
# 2                              23.75      2023-01-25
# 3                              14.59      2023-02-02
# 4                              22.17      2023-06-20
#
#   nature_of_payment_or_transfer_of_value form_of_payment_or_transfer_of_value  \
# 0                      Food and Beverage              Cash or cash equivalent
# 1                      Food and Beverage              Cash or cash equivalent
# 2                      Food and Beverage              Cash or cash equivalent
# 3                      Food and Beverage           In-kind items and services
# 4                      Food and Beverage           In-kind items and services
#
#    number_of_payments_included_in_total_amount  record_id  \
# 0                                            1  966803191
# 1                                            1  966803197
# 2                                            1  966803203
# 3                                            1  966519119
# 4                                            1  966519125
#
#    physician_ownership_indicator  program_year
# 0                          False          2023
# 1                          False          2023
# 2                          False          2023
# 3                          False          2023
# 4                          False          2023

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14672763 entries, 0 to 14704232
# Data columns (total 22 columns):
#  #   Column                                                         Dtype
# ---  ------                                                         -----
#  0   covered_recipient_profile_id                                   Int64
#  1   covered_recipient_npi                                          Int64
#  2   covered_recipient_first_name                                   object
#  3   covered_recipient_last_name                                    object
#  4   covered_recipient_specialty_1                                  object
#  5   covered_recipient_primary_type_1                               object
#  6   covered_recipient_license_state_code1                          object
#  7   recipient_city                                                 object
#  8   recipient_state                                                object
#  9   recipient_zip_code                                             object
#  10  recipient_zip_5                                                object
#  11  applicable_manufacturer_or_applicable_gpo_making_payment_id    Int64
#  12  applicable_manufacturer_or_applicable_gpo_making_payment_name  object
#  13  name_of_drug_or_biological_or_device_or_medical_supply_1       object
#  14  total_amount_of_payment_usdollars                              float64
#  15  date_of_payment                                                datetime64[ns]
#  16  nature_of_payment_or_transfer_of_value                         object
#  17  form_of_payment_or_transfer_of_value                           object
#  18  number_of_payments_included_in_total_amount                    Int64
#  19  record_id                                                      Int64
#  20  physician_ownership_indicator                                  boolean
#  21  program_year                                                   Int64
# dtypes: Int64(6), boolean(1), datetime64[ns](1), float64(1), object(13)
# memory usage: 2.5+ GB

# %%
df['nature_of_payment_or_transfer_of_value'].value_counts()
# Out:
# nature_of_payment_or_transfer_of_value
# Food and Beverage                                                                                                                                     13457311
# Travel and Lodging                                                                                                                                      552420
# Compensation for services other than consulting, including serving as faculty or as a speaker at a venue other than a continuing education program      231114
# Consulting Fee                                                                                                                                          173687
# Education                                                                                                                                               161565
# Gift                                                                                                                                                     31806
# Honoraria                                                                                                                                                21109
# Royalty or License                                                                                                                                       14443
# Compensation for serving as faculty or as a speaker for a medical education program                                                                      12336
# Entertainment                                                                                                                                             8043
# Long term medical supply or device loan                                                                                                                   4134
# Grant                                                                                                                                                     3001
# Debt forgiveness                                                                                                                                          1062
# Acquisitions                                                                                                                                               624
# Charitable Contribution                                                                                                                                    108
# Name: count, dtype: int64

# %%
useful_natures = [
    "Compensation for services other than consulting, including serving as faculty or as a speaker at a venue other than a continuing education program",
    "Consulting Fee",
    "Education",
    "Honoraria",
    "Royalty or License",
    "Compensation for serving as faculty or as a speaker for a medical education program",
    "Long term medical supply or device loan",
    "Grant",
]

print(len(df))
df = df[df['nature_of_payment_or_transfer_of_value'].isin(useful_natures)]
print(len(df))
# Out:
# 14672763
# 621389
